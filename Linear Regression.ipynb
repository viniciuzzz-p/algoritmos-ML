# %%
try:
    import matplotlib
    print("✅ Sucesso! Você TEM o matplotlib instalado.")
    print(f"Versão: {matplotlib.__version__}")
except ImportError:
    print("❌ Erro! Você NÃO tem o matplotlib instalado.")
# Out:
# ✅ Sucesso! Você TEM o matplotlib instalado.
# Versão: 3.10.8
